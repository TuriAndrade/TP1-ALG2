# %% [markdown]
# #### Impedindo notebook de escrever bytecode

# %%
import sys
sys.dont_write_bytecode = True

# %% [markdown]
# #### Inserindo caminho dos módulos em sys.path

# %%
import pathlib
import os
sys.path.append(str(pathlib.Path(os.getcwd()).parent.parent.resolve()))

# %% [markdown]
# #### Importando módulos

# %%
from modules.point import PointDataset
from modules.classifier import ConvexHullClassifier, KNNClassifier, ClassifiersComparison
from random import choices
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Lendo dataset

# %%
dataset = PointDataset("./data.dat")
points = dataset.getPoints()

# %% [markdown]
# #### Criando construtor de instância do classificador baseado em envoltória convexa para as features (0, 1)

# %%
CHclf01 = ConvexHullClassifier.buildInstance(name="ConvexHullClassifier01", coordinate1=0, coordinate2=1, nFolds=5)

# %% [markdown]
# #### Criando construtor de instância do classificador baseado em envoltória convexa para as features (0, 2)

# %%
CHclf02 = ConvexHullClassifier.buildInstance(name="ConvexHullClassifier02", coordinate1=0, coordinate2=2, nFolds=5)

# %% [markdown]
# #### Criando construtor de instância do classificador baseado em envoltória convexa para as features (1, 2)

# %%
CHclf12 = ConvexHullClassifier.buildInstance(name="ConvexHullClassifier12", coordinate1=1, coordinate2=2, nFolds=5)

# %% [markdown]
# #### Criando construtor de instância do classificador KNN com otimização iterativa do número de vizinhos

# %% [markdown]
# A otimização é feita da seguinte forma: validação cruzada com 5 folds é executada para classificador, variando o número de vizinhos de 1 a _maxK_. É escolhido o número de vizinhos que apresenta a melhor _F1 Score_ média entre os folds. Se _makK_ não for passado, _maxK_ é igual à raíz quadrada do tamanho do dataset.

# %%
KNNclf = KNNClassifier.buildInstance(maxK=30, nFolds=5)

# %% [markdown]
# #### Comparação da diferença média para as métricas _Precisão_, _Sensibilidade_, _F1 Score_ e _Acurácia_ entre os classificadores par a par

# %% [markdown]
# Para efeutar a comparação, um bootstrapping foi feito usando 100 amostras com reposição e 100 indivíduos em cada uma delas.

# %%
clfComparison = ClassifiersComparison(points, [KNNclf, CHclf01, CHclf02, CHclf12], sampleSize=100, nSamples=100)
meanDiff = clfComparison.run()
meanDiff
# Out:
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:70: RuntimeWarning: invalid value encountered in long_scalars
#   recall: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:70: RuntimeWarning: invalid value encountered in long_scalars
#   recall: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:70: RuntimeWarning: invalid value encountered in long_scalars
#   recall: float = confusionMatrix[0][0] / \
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:70: RuntimeWarning: invalid value encountered in long_scalars
#   recall: float = confusionMatrix[0][0] / \
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:70: RuntimeWarning: invalid value encountered in long_scalars
#   recall: float = confusionMatrix[0][0] / \
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:70: RuntimeWarning: invalid value encountered in long_scalars
#   recall: float = confusionMatrix[0][0] / \
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:70: RuntimeWarning: invalid value encountered in long_scalars
#   recall: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:70: RuntimeWarning: invalid value encountered in long_scalars
#   recall: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:61: RuntimeWarning: invalid value encountered in long_scalars
#   precision: float = confusionMatrix[0][0] / \
# /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifier.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2*precision*recall)/(precision + recall)
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# ...
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#
#
# Warning: Invalid number of different points.
# Traceback stack:
# -----------------------------------------------------------------------
# File: /tmp/ipykernel_994/808624011.py
# Line: 2
# Call: meanDiff = clfComparison.run()
# -----------------------------------------------------------------------
# File: /home/turi/aulas/5sem/ALG2/TP1/modules/classifier/classifiersComparison.py
# Line: 64
# Call: comparison: pd.DataFrame = self.compare2(
#      Precision    Recall        F1  Accuracy  \
# 0     0.200000 -0.333333  0.200000  0.366667
# 1     0.500000  0.232143  0.500000 -0.033333
# 2     0.066667  0.357143  0.066667  0.100000
# 3     0.100000 -0.916667  0.100000  0.333333
# 4    -0.300000 -0.083333 -0.300000 -0.166667
# ..         ...       ...       ...       ...
# 905   0.500000  0.083333       NaN  0.000000
# 906        NaN  0.000000       NaN  0.000000
# 907   1.000000  0.166667       NaN  0.066667
# 908   0.000000 -0.025000  0.000000 -0.066667
# 909   0.500000  0.090909       NaN  0.066667
#
#                                              Label
# 0             KNNClassifier/ConvexHullClassifier01
# 1             KNNClassifier/ConvexHullClassifier01
# 2             KNNClassifier/ConvexHullClassifier01
# 3             KNNClassifier/ConvexHullClassifier01
# 4             KNNClassifier/ConvexHullClassifier01
# ..                                             ...
# 905  ConvexHullClassifier12/ConvexHullClassifier02
# 906  ConvexHullClassifier12/ConvexHullClassifier02
# 907  ConvexHullClassifier12/ConvexHullClassifier02
# 908  ConvexHullClassifier12/ConvexHullClassifier02
# 909  ConvexHullClassifier12/ConvexHullClassifier02
#
# [910 rows x 5 columns]

# %% [markdown]
# #### Plot dos histogramas de diferença média para as métricas entre os classificadores KNN e Convex Hull para as features (0, 1)

# %%
clfComparison.plotPairComparison('KNNClassifier/ConvexHullClassifier01')

# %% [markdown]
# #### Plot dos histogramas de diferença média para as métricas entre os classificadores KNN e Convex Hull para as features (0, 2)

# %%
clfComparison.plotPairComparison('KNNClassifier/ConvexHullClassifier02')

# %% [markdown]
# #### Plot dos histogramas de diferença média para as métricas entre os classificadores KNN e Convex Hull para as features (1, 2)

# %%
clfComparison.plotPairComparison('KNNClassifier/ConvexHullClassifier12')
